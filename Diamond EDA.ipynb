# %% [markdown]
# #### Importing neccssary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import random

# %% [markdown]
# #### Preprocessing
# Exploring data

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo\\desktop\\Imarticus\\python'

# %%
data = sns.get_dataset_names()
# data

# %%
diamond = sns.load_dataset('diamonds')
diamond
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamond.head(10)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %%
diamond.tail(10)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53930   0.71    Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53931   0.71    Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53932   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71  5.76  3.47
# 53933   0.70  Very Good     E     VS2   61.2   59.0   2757  5.69  5.72  3.49
# 53934   0.72    Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
diamond.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
diamond.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
diamond.columns #to get all the columns of the data
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
diamond.isnull().any()  #to check if there are any null values
# Out:
# carat      False
# cut        False
# color      False
# clarity    False
# depth      False
# table      False
# price      False
# x          False
# y          False
# z          False
# dtype: bool

# %%
diamond["cut"].value_counts() #to get number of each class of 'cut' variable
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %%
diamond["clarity"].value_counts() #to get number of each class of 'clarity' variable
# Out:
# clarity
# SI1     13065
# VS2     12258
# SI2      9194
# VS1      8171
# VVS2     5066
# VVS1     3655
# IF       1790
# I1        741
# Name: count, dtype: int64

# %% [markdown]
# #### To sort the values of categoric variables as "ordinal"

# %%
# from the worst (fair) to the best (ideal)

cut_categories = ["Fair", "Good", "Very Good", "Premium", "Ideal"]
diamond['cut'] = pd.Categorical(diamond['cut'], categories=cut_categories, ordered=True)

# %%
cut_categories
# Out:
# ['Fair', 'Good', 'Very Good', 'Premium', 'Ideal']

# %%
clarity_categories = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]
diamond["clarity"] = pd.Categorical(diamond['clarity'],categories = clarity_categories,ordered=True)

# %%
clarity_categories
# Out:
# ['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF']

# %% [markdown]
# #### Data visualization

# %% [markdown]
# ##### bar plot

# %%
#calculate frequencies
cut_frequencies = diamond["cut"].value_counts(ascending=True)
# Extract x and y values for the plot
x = cut_frequencies.values
y = cut_frequencies.index

# Plot the bar chart
plt.bar(y, x, color='red')
plt.title("Class frequencies of 'cut' variable")
plt.xlabel('Frequency')
plt.ylabel('Cut Category')
plt.show()

# %%
# For 'cut' variable
sns.barplot(x = diamond["cut"].value_counts().index,
            y = diamond["cut"].value_counts(),
            data = diamond,
            saturation = 1);
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
# For 'color' variable
sns.barplot(x = diamond["color"].value_counts().index,
            y = diamond["color"].value_counts(),
            data = diamond,
            saturation = 1);
plt.title("Barplot for diamond")
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# Text(0.5, 1.0, 'Barplot for diamond')

# %%
sns.catplot(x = "cut",
            y = "price",
            kind = "strip",
            data = diamond,
            margin_titles = True);
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.catplot(x = "clarity",
            y = "price",
            kind = "strip",
            data = diamond,
            margin_titles = True);
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.catplot(y="price",
            x="clarity",
            kind="box",
            color= '#abc9ea',
            data=diamond).set(yscale="log");
plt.title("Boxplot of Diamond Prices by Clarity")
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.barplot(x = "cut", y = "price", hue = "color", data = diamond, saturation = 1);
plt.title("Average Price by Cut and Color")
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
# Here we validate what our last graphic show us
diamond.groupby(["cut", "color"])["price"].mean()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13936\801352014.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   diamond.groupby(["cut", "color"])["price"].mean()
# cut        color
# Fair       D        4291.061350
#            E        3682.312500
#            F        3827.003205
#            G        4239.254777
#            H        5135.683168
#            I        4685.445714
#            J        4975.655462
# Good       D        3405.382175
#            E        3423.644159
#            F        3495.750275
#            G        4123.482204
#            H        4276.254986
#            I        5078.532567
#            J        4574.172638
# Very Good  D        3470.467284
#            E        3214.652083
#            F        3778.820240
#            G        3872.753806
# ...

# %%
sns.barplot(x = "cut", y = "price", hue = "clarity", data = diamond,
            saturation = 1);
plt.title("Average Price by Clarity and Color")
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
# Here we validate what our last graphic show us

diamond.groupby(["cut", "clarity"])["price"].mean()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13936\1236293301.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   diamond.groupby(["cut", "clarity"])["price"].mean()
# cut        clarity
# Fair       I1         3703.533333
#            SI2        5173.916309
#            SI1        4208.279412
#            VS2        4174.724138
#            VS1        4165.141176
#            VVS2       3349.768116
#            VVS1       3871.352941
#            IF         1912.333333
# Good       I1         3596.635417
#            SI2        4580.260870
#            SI1        3689.533333
#            VS2        4262.236196
#            VS1        3801.445988
#            VVS2       3079.108392
#            VVS1       2254.774194
#            IF         4098.323944
# Very Good  I1         4078.226190
# ...

# %% [markdown]
# ### Histogram and density plot

# %%
sns.distplot(diamond["price"],
             hist = True,
             bins = 30,
             kde = True,
             norm_hist = False,
             vertical = False, color = "g");

print(diamond.price.describe().T)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13936\3796565772.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(diamond["price"],
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# count    53940.000000
# mean      3932.799722
# std       3989.439738
# min        326.000000
# 25%        950.000000
# 50%       2401.000000
# 75%       5324.250000
# max      18823.000000
# Name: price, dtype: float64

# %%
(sns.FacetGrid(diamond,
              hue = "cut",
              height = 7,
              xlim = (0, 10000))
 .map(sns.kdeplot, "price", shade = True)
 .add_legend()
);
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# ...

# %% [markdown]
# ### Boxplot

# %%
sns.boxplot(x = "cut", y = "price", data = diamond, width = 0.7,
            orient = "v",
            fliersize = 2, linewidth = 1);
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.boxplot(x = "color", y = "price", data = diamond, width = 0.7,
            orient = "v",
            fliersize = 2, linewidth = 1);
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.boxplot(x = "cut", y = "carat", data = diamond, width = 0.7,
            orient = "v",
            fliersize = 2, linewidth = 1);
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# ### Scatterplot

# %%
df1 = diamond.sample(frac = 0.2) #to get 20% of dataset

plt.figure(figsize = (6, 4))
sns.scatterplot(x = "carat",
                y = "price",
                data = df1).set(title = 'Relationship between Price and Carat');

# %% [markdown]
# ### Pairplot

# %%
#correlation between variables of dataset
sns.pairplot(df1);
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
